# %% [markdown]
# <a href="https://colab.research.google.com/github/RitaDCassia/data_analysis/blob/main/amostragem_estratificada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
iris = pd.read_csv('iris.csv')
iris['class'].value_counts()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
iris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# klearn.model_selection usada para dividir matrizes ou dataframes em subconjuntos aleatórios de treino e teste.
# iris.iloc[:, 0:4] -> busca apenas os atributos previsores, os dados sobre a pétala
# e a sétala da planta
# iris.iloc[:, 4] -> Busca domente a classe que é a especie da planta (setosa, virginica ou visicolor)
# test_size=0.5 -> selecionamos 50% da base de dados, que serao copiados para as
# variaveis x e y, essa funcao retorna 4 valores. porém vamos usar domente os 50%
# da base de dados e por isso colocamos "_" para os outros valores
# stratify= iris.iloc[:, 4] -> para tornar a amostra baseadad na classe, amostra estratidicada da coluna 4
x, _, y, _, = train_test_split(iris.iloc[:, 0:4], iris.iloc[:, 4],
                               test_size=0.5, stratify= iris.iloc[:, 4])

y.value_counts()
# Out:
# class
# Iris-versicolor    25
# Iris-setosa        25
# Iris-virginica     25
# Name: count, dtype: int64

# %%
infert = pd.read_csv('infert.csv')
infert
# Out:
#      Unnamed: 0 education  age  parity  induced  case  spontaneous  stratum  \
# 0             1    0-5yrs   26       6        1     1            2        1
# 1             2    0-5yrs   42       1        1     1            0        2
# 2             3    0-5yrs   39       6        2     1            0        3
# 3             4    0-5yrs   34       4        2     1            0        4
# 4             5   6-11yrs   35       3        1     1            1        5
# ..          ...       ...  ...     ...      ...   ...          ...      ...
# 243         244   12+ yrs   31       1        0     0            1       79
# 244         245   12+ yrs   34       1        0     0            0       80
# 245         246   12+ yrs   35       2        2     0            0       81
# 246         247   12+ yrs   29       1        0     0            1       82
# 247         248   12+ yrs   23       1        0     0            1       83
#
#      pooled.stratum
# 0                 3
# ...

# %%
infert['education'].value_counts()
# Out:
# education
# 6-11yrs    120
# 12+ yrs    116
# 0-5yrs      12
# Name: count, dtype: int64

# %%
# criando amostra com semente 40% dos registros (por isso é definido 0.6, pois é gereado o inverso)
x1, _, y1, _ = train_test_split(infert.iloc[:, 2:9], infert.iloc[:, 1],
                                test_size=0.6, stratify=infert.iloc[:,1])
y1.value_counts()
# Out:
# education
# 6-11yrs    48
# 12+ yrs    46
# 0-5yrs      5
# Name: count, dtype: int64
